# %%
print(5//4)
print(8%3)
print(66-84)
print(34+1976596)
print(2**4)
print(8/3)
print(8//3)
# Out:
# 1
# 2
# -18
# 1976630
# 16
# 2.6666666666666665
# 2

# %%
3 + int("7")
4.1 + float("4.3") * 2
# Out:
# 12.7

# %%
# 寫了很多行運算式，python在執行完每一行運算式的工作後就會將結果丟棄，所以需要將運算式的結果做儲存才有意義。
# 等號是將運算式指定成為敘述式，建立記憶體區塊儲存運算式結果
# 1 + 2 + 3這樣只是運算式(expression)，運算式會產生傳出值
# 加上等號就會變成敘述式(statement)，敘述式不會產生傳出值
#bbb = 1 + 2 + 3
#bbb
#以上表示建立名為bbb的記憶體區塊，在最後一行將記憶體區塊內的值傳出。記憶體區塊可以任意命名

# 複合指定運算子 += 表示將左邊的變數執行等號左邊的運算元去處理等號右邊的運算子 
# bb += 5 意思就是將bb這個變數加上五儲存回bb這個變數

bb= 3
bb **= 2
bb
# Out:
# 9

# %%
#機器學習外部套件 Numpy; 科學用 Scipy
# import math 引入math外部函式庫，後面才能引用開根號函式sqrt，語法為math.sqrt
# import numpy as np 引入numpy外部函式庫並簡寫為np，語法為np.sqrt
import math
a = 4
b = math.sqrt(a)
b
# Out:
# 2.0

# %%
weight = 72
height = 175
height /= 100
BMI = round(weight / height**2, 2)
BMI
# Out:
# 23.51

# %%
練習題：計算體重指數 BMI
BMI（Body Mass Index，身體質量指數）是評估體重是否健康的常用指標。

計算公式：
BMI = 體重(公斤) ÷ 身高(公尺)²

題目要求：

建立變數 weight 儲存體重 72 公斤
建立變數 height 儲存身高 175 公分（注意：公式需要公尺，請先除以 100）
使用 ** 運算子計算身高的平方
計算 BMI 值並儲存在變數 bmi 中
使用 round() 函式將 BMI 四捨五入到小數點後 2 位
印出結果
參考輸出：
23.35

提示：

身高需轉換成公尺：height = 175 / 100
平方使用 ** 運算子：height ** 2
四捨五入：round(bmi, 2)
